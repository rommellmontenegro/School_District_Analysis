# %% [markdown]
# # ***MM LINKS Tables***

# %%
import os
import pandas as pd
import time
from time import mktime
import datetime
from datetime import datetime

currentDateTime = datetime.now()
date = currentDateTime.date()
year = date.strftime("%Y") #except: 2022

date.strftime("%Y")

d = datetime.now()
only_date, only_time = d.date(), d.time()
only_date = only_date.strftime('%Y.%m.%d')
only_time = only_time.strftime('%H.%M')
procTS = str(only_date) + "_" + str(only_time)


# Get the list of all files and directories
path = "/Users/rommellmontenegro/Desktop/Civil Suit*/5 - Mobile Graphic & Video Media/RICO Album Tables/Combine/MM Links"
dir_list = os.listdir(path)
dir_list.sort()
dir_list = dir_list[:]
dir_list

gt1 = pd.DataFrame(columns=['name', 'id', 'webViewLink', 'timestamp', 'year', 'month', 'date', 'hour', 'min', 'sec', 'Ftype', 'file size', 'size_MB', 'Date-Time Processed'])

for i in dir_list:
    if not file_name.startswith('.'):
        gt2 = pd.read_excel(path + "/" + i)
        gt2 = gt2[['name', 'id', 'webViewLink', 'timestamp', 'year', 'month', 'date', 'hour', 'min', 'sec', 'Ftype', 'file size', 'size_MB', 'Date-Time Processed']]
        gt1 = pd.concat([gt1, gt2], ignore_index=True)
    
gt1 = gt1.drop_duplicates()
gt1

# %%
output = "/Users/rommellmontenegro/Desktop/Civil Suit*/5 - Mobile Graphic & Video Media/RICO Album Tables/Combine/"
tabname = "Dating Fraud"

FileName = output + " " + tabname + " Combined.xlsx"

column_order = ['name', 'id', 'webViewLink', 'timestamp', 'year', 'month', 'date', 'hour', 'min', 'sec', 'ftype', 'file size', 'size_MB', 'Date-Time Processed']
with pd.ExcelWriter(FileName) as writer:
    gt1[column_order].to_excel(writer, sheet_name=tabname)

# %% [markdown]
# # ***Mobile Album Tables***

# %%
import os
import pandas as pd

# Get the list of all files and directories
path = "/Users/rommellmontenegro/Desktop/Civil Suit*/5 - Mobile Graphic & Video Media/RICO Album Tables/Combine/Albums"
dir_list = os.listdir(path)
dir_list.sort()
dir_list = dir_list[:]
dir_list

df1 = pd.DataFrame(columns = ['location','path', 'timestamp', 'year', 'month', 'date', 'hour', 'min', 'sec','filesize','date-time processed', 'date-time created', 'date-time modified', 'album', 'ftype', 'filename', 'size_GB', 'size_MB',  'webViewLink'])

for i in dir_list:
    if not i.startswith('.'):
        df2 = pd.read_excel(path + "/" + i)
        df2 = df2[['location','path', 'timestamp', 'year', 'month', 'date', 'hour', 'min', 'sec','filesize','date-time processed', 'date-time created', 'date-time modified', 'album', 'ftype', 'filename', 'size_GB', 'size_MB',  'webViewLink']]
        df1 = pd.concat([df1, df2], ignore_index=True)
    
df1 = df1.drop_duplicates()

# %%
import os
import pandas as pd
import time
from time import mktime
import datetime
from datetime import datetime

currentDateTime = datetime.now()
date = currentDateTime.date()
year = date.strftime("%Y") #except: 2022

date.strftime("%Y")

d = datetime.now()
only_date, only_time = d.date(), d.time()
only_date = only_date.strftime('%Y.%m.%d')
only_time = only_time.strftime('%H.%M')
procTS = str(only_date) + "_" + str(only_time)

#PC = 14
PC = "Both"
output = "/Users/rommellmontenegro/Desktop/Civil Suit*/5 - Mobile Graphic & Video Media/RICO Album Tables/Combine/"
if PC == 14:
    tabname0 = "All '14' Albums"
elif PC == "Both":
    tabname0 = "All Albums"
else:
    tabname0 = "All '13' Albums"

FileName = output + only_date + "_" + only_time + " " + tabname0 + " Combined.xlsx"

column_order = ['location','path', 'timestamp', 'year', 'month', 'date', 'hour', 'min', 'sec','filesize','date-time processed', 'date-time created', 'date-time modified', 'album', 'ftype', 'filename', 'size_GB', 'size_MB',  'webViewLink']

n1 = int(len(df1)/2)
n2 = int(len(df1) - n1)
n01 = n1+1

tab1 = df1[:n1]
tab2 = df1[n01:]

tabname1 = tabname0 + " 1"
tabname2 = tabname0 + " 2"

with pd.ExcelWriter(FileName) as writer:
    tab1[column_order].to_excel(writer, sheet_name=tabname1, index=False)
    tab2[column_order].to_excel(writer, sheet_name=tabname2, index=False)

# %% [markdown]
# # ***Validated Folder Tables***

# %%
import os
import pandas as pd
import time
from time import mktime
import datetime
from datetime import datetime

currentDateTime = datetime.now()
date = currentDateTime.date()
year = date.strftime("%Y") #except: 2022

date.strftime("%Y")

d = datetime.now()
only_date, only_time = d.date(), d.time()
only_date = only_date.strftime('%Y.%m.%d')
only_time = only_time.strftime('%H.%M')
procTS = str(only_date) + "_" + str(only_time)

# Get the list of all files and directories
path = "/Users/rommellmontenegro/Desktop/Civil Suit*/5 - Mobile Graphic & Video Media/RICO Album Tables/Combine/Google Files/Validated"
dir_list = os.listdir(path)
dir_list.sort()
dir_list = dir_list[:]
dir_list

df1 = pd.DataFrame(columns = ['count', 'filename', 'name', 'id', 'webViewLink', 'File Type', 'path', 'MB_size'])

for i in dir_list:
    if not i.startswith('.'):
        df2 = pd.read_excel(path + "/" + i)
        df2 = df2[['count', 'filename', 'name', 'id', 'webViewLink', 'File Type', 'path', 'MB_size']]
        df1 = pd.concat([df1, df2], ignore_index=True)
    
df1 = df1.drop_duplicates()
df1.drop(df1[df1['name'] == '.DS_Store'].index, inplace=True)
    
output = "/Users/rommellmontenegro/Desktop/Civil Suit*/5 - Mobile Graphic & Video Media/RICO Album Tables/Combine/Google Folders/"
tabname = "All Validated Folders"
FileName = output + only_date + "_" + only_time + " " + tabname + " Combined.xlsx"

column_order = ['count', 'filename', 'name', 'id', 'webViewLink', 'File Type', 'path', 'MB_size']
with pd.ExcelWriter(FileName) as writer:
    df1[column_order].to_excel(writer, sheet_name=tabname)
df1
# Out:
# /var/folders/5k/m2kjbr8969j9g5j1fq8vnxkm0000gn/T/ipykernel_50847/818468456.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df1 = pd.concat([df1, df2], ignore_index=True)
#     count                                           filename  \
# 0       7  2025.05.07_22.09_Legal Case_(7)_GDrive_Files.xlsx
# 1       8  2025.05.07_22.08_Mobile Graphic & Video Media_...
# 2       9     2025.05.07_22.09_Records_(9)_GDrive_Files.xlsx
# 3      26    2025.05.07_22.08_Reports_(26)_GDrive_Files.xlsx
# 4       5  2025.05.07_22.08_Private Audio_(5)_GDrive_File...
# ..    ...                                                ...
# 760    11   2025.05.07_22.05_Payments_(11)_GDrive_Files.xlsx
# 761    15  2025.05.07_22.05_Communication_(15)_GDrive_Fil...
# ...

# %% [markdown]
# # ***Google Drive Files***

# %%
import os
import pandas as pd
import time
from time import mktime
import datetime
from datetime import datetime

currentDateTime = datetime.now()
date = currentDateTime.date()
year = date.strftime("%Y") #except: 2022

date.strftime("%Y")

d = datetime.now()
only_date, only_time = d.date(), d.time()
only_date = only_date.strftime('%Y.%m.%d')
only_time = only_time.strftime('%H.%M')
dir_list = []

# Get the list of all files and directories
path = "/Users/rommellmontenegro/Desktop/Civil Suit*/5 - Mobile Graphic & Video Media/RICO Album Tables/Combine/Google Files/"
date = "2025.05.07/"
dir_list = os.listdir(path + date)
dir_list.sort()
dir_list = dir_list[:]
dir_list

df1 = pd.DataFrame(columns = ['name', 'id', 'webViewLink', 'File Type', 'date-time processed', 'MB_size','Folder', 'path', 'Locked'])

for i in dir_list:
    if not i.startswith('.'):
        df2 = pd.read_excel(path + date + i)
        df2 = df2[['name', 'id', 'webViewLink', 'File Type', 'date-time processed', 'MB_size','Folder', 'path', 'Locked']]
        df1 = pd.concat([df1, df2], ignore_index=True)
    
df1 = df1.drop_duplicates()
df1.drop(df1[df1['name'] == '.DS_Store'].index, inplace=True)
    
output = "/Users/rommellmontenegro/Desktop/Civil Suit*/5 - Mobile Graphic & Video Media/RICO Album Tables/Combine/"
tabname = "All Files"
FileName = output + only_date + "_" + only_time + " " + tabname + " Combined.xlsx"

column_order = ['name', 'id', 'webViewLink', 'File Type', 'date-time processed', 'MB_size','Folder', 'path', 'Locked']
with pd.ExcelWriter(FileName) as writer:
    df1[column_order].to_excel(writer, sheet_name=tabname)
df1
# Out:
#                                                     name  \
# 0        2023.4.16 - Vibration After Beds Deconstruction
# 1                           Vibration Reported to Police
# 2                                  2023.4.14 - Vibration
# 3                                  2023.4.21 - Vibration
# 4      2023.5.11 - Record of Vibration (Security Camera)
# ...                                                  ...
# 58284        Screenshot 2023-05-17 at 7.39.17 AM (2).png
# 58285      Screen Recording 2023-05-09 at 6.58.40 AM.mov
# 58286                       IMG_8686_20230422_001422.jpg
# 58287                       IMG_2787_20230422_000958.JPG
# 58288                       IMG_5069_20230310_200739.JPG
#
#                                       id  \
# 0      1-ME20lbgShiHBTXA8A1019jUoKLvj3ZU
# 1      18CloiUaKguqM-3JB7MN5whynfXguP9J4
# 2      1sxZKsOay9r_A-xa-XfOrHjUp1EE2XdLT
# 3      1ryxccEYr_TTD6I5xw0hbQAVk3MPM_5eB
# 4      1WX-IOx0LvXKgILCfSQnwqUfyz3sGmg2l
# ...

# %% [markdown]
# # ***Google Path Files***

# %%
import os
import pandas as pd
import time
from time import mktime
import datetime
from datetime import datetime
import shutil 

# Get the list of all files and directories
path = "/Users/rommellmontenegro/Desktop/Civil Suit*/5 - Mobile Graphic & Video Media/RICO Album Tables/Combine/Google Path"
dir_list = os.listdir(path)
dir_list.sort()
dir_list = dir_list[:]
dir_list
output = "/Users/rommellmontenegro/Desktop/Civil Suit*/5 - Mobile Graphic & Video Media/RICO Album Tables/Combine/Past Combinations/Google Path/"
df1 = pd.DataFrame(columns = ['id', 'name', 'webViewLink', 'path'])

for i in dir_list:
    if not i.startswith('.' or '~'):
        df2 = pd.read_excel(path + "/" + i)
        df2 = df2[['path','name', 'id', 'webViewLink']]
        df1 = pd.concat([df1, df2], ignore_index=True)
    des = output + i[0:10] + "/"
    if not i.startswith('.' or '~'):
        if not os.path.exists(des):
            os.makedirs(des)
        shutil.move(path + "/" + i, des + i)

df1 = df1.drop_duplicates()

currentDateTime = datetime.now()
date = currentDateTime.date()
year = date.strftime("%Y") #except: 2022

date.strftime("%Y")

d = datetime.now()
only_date, only_time = d.date(), d.time()
only_date = only_date.strftime('%Y.%m.%d')
only_time = only_time.strftime('%H.%M')

tabname = "GDrivePath"
FileName = output + i[0:10] + "/" + only_date + "_" + only_time + " " + tabname + " Combined.xlsx"

column_order = ['id', 'name', 'webViewLink', 'path']
with pd.ExcelWriter(FileName) as writer:
    df1[column_order].to_excel(writer, sheet_name=tabname, index=True)
    
legal0 = df1[df1['path'].str.contains('LEGAL')]

legal1 = legal0[~legal0.path.str.contains("Admin")]

exclude_list = ['Video Diary - rommellvega', '*Admin', 'Dating App Fraud', '1311 Ironwood Audio Recordings']
legal = legal1[~legal1['name'].isin(exclude_list)]

FolderLists = '/Users/rommellmontenegro/Desktop/Civil Suit*/5 - Mobile Graphic & Video Media/RICO Album Tables/ADMIN-Working Files/GDrive Folder Lists/'
column_order = ['id', 'name', 'webViewLink', 'path']
n = int(len(legal)/5)+1

tab1 = legal[:n]
tab2 = legal[n:2*n]
tab3 = legal[2*n:3*n]
tab4 = legal[3*n:4*n]
tab5 = legal[4*n:]

tabname = "GDrive_LEGAL_Folders"

tabname1 = tabname + " 1"
tabname2 = tabname + " 2"
tabname3 = tabname + " 3"
tabname4 = tabname + " 4"
tabname5 = tabname + " 5"

FileName = FolderLists + only_date + "_" + only_time + " GDrive_LEGAL_Folders 1.xlsx"

with pd.ExcelWriter(FileName) as writer:
    tab1[column_order].to_excel(writer, sheet_name=tabname1, index=True)
    
FileName = FolderLists + only_date + "_" + only_time + " GDrive_LEGAL_Folders 2.xlsx"

with pd.ExcelWriter(FileName) as writer:    
    tab2[column_order].to_excel(writer, sheet_name=tabname2, index=True)

FileName = FolderLists + only_date + "_" + only_time + " GDrive_LEGAL_Folders 3.xlsx"

with pd.ExcelWriter(FileName) as writer:
    tab3[column_order].to_excel(writer, sheet_name=tabname3, index=True)

FileName = FolderLists + only_date + "_" + only_time + " GDrive_LEGAL_Folders 4.xlsx"

with pd.ExcelWriter(FileName) as writer:
    tab4[column_order].to_excel(writer, sheet_name=tabname4, index=True)

FileName = FolderLists + only_date + "_" + only_time + " GDrive_LEGAL_Folders 5.xlsx"

with pd.ExcelWriter(FileName) as writer:
    tab5[column_order].to_excel(writer, sheet_name=tabname5, index=True)

FolderLists = '/Users/rommellmontenegro/Desktop/Civil Suit*/5 - Mobile Graphic & Video Media/RICO Album Tables/ADMIN-Working Files/GDrive Folder Lists/'

FileName = FolderLists + only_date + "_" + only_time + " GDrive_LEGAL_Folders.xlsx"

with pd.ExcelWriter(FileName) as writer:
    legal[column_order].to_excel(writer, sheet_name=tabname, index=True)
    tab1[column_order].to_excel(writer, sheet_name=tabname1, index=True)
    tab2[column_order].to_excel(writer, sheet_name=tabname2, index=True)
    tab3[column_order].to_excel(writer, sheet_name=tabname3, index=True)
    tab4[column_order].to_excel(writer, sheet_name=tabname4, index=True)
    tab5[column_order].to_excel(writer, sheet_name=tabname5, index=True)

# %%
legal
# Out:
#                                      id  \
# 650   1CXbxo5lFw_9La_uX81DT7TK-O7jOpCC7
# 651   1ioa4eJyv5IiaDtxhbn6VGjoS30HGhyYg
# 652   1rEX-AMTBx7EYdHnntTHWX8Ra9mfY40NE
# 653   15G7_fBtLtXq6paBl8jfoofkeh4CPPsbq
# 654   1Cm4AoGbabhpoitAxaRALv9IETTQMaIWs
# ...                                 ...
# 9246  1iPXcGZNbOK_9HpNMCz0pc7F-28M-DIL5
# 9247  1Ckc_S7iz-Wr5ofYPlzgeEJYH5Tb8MpRO
# 9248  1l40ucGSba3-6rOpq_K8XQ_8SqjdocKFA
# 9249  1L36pxJs9RkL2otNzP3rfwPFlTseeF7te
# 9252  1Ti_Q4REDOehp-9TusI0TgZQvH7RsqPrq
#
#                                                    name  \
# 650                                      IP Theft Claim
# 651                                         Non-Profits
# 652                                              CA HUD
# 653                          CA Civil Rights Department
# 654                                   Manager Liability
# ...                                                 ...
# 9246                     State of California Interviews
# ...

# %% [markdown]
# # ***Google Lock Errors***

# %%
import os
import pandas as pd
import time
from time import mktime
import datetime
from datetime import datetime

# Get the list of all files and directories
path = "/Users/rommellmontenegro/Desktop/Civil Suit*/5 - Mobile Graphic & Video Media/RICO Album Tables/Combine/GDrive Lock Errors"
dir_list = os.listdir(path)
dir_list.sort()
dir_list = dir_list[:]
dir_list
output = "/Users/rommellmontenegro/Desktop/Civil Suit*/5 - Mobile Graphic & Video Media/RICO Album Tables/Combine/Past Combinations/Google Path/"

df1 = pd.DataFrame(columns = ['Gids', 'Filename', 'Errortype', 'ErrorIssue', 'Path', 'webViewLink'])
#df1.rename(columns={'Errors': 'FileName'}, inplace=True)
                              
for i in dir_list:
    if not i.startswith('.'):
        df2 = pd.read_excel(path + "/" + i)
        df2 = df2[['Gids','Filename', 'Errortype', 'ErrorIssue', 'Path', 'webViewLink']]
        df1 = pd.concat([df1, df2], ignore_index=True)
    
df1 = df1.drop_duplicates()
df1.rename(columns={'Gids': 'id'}, inplace=True)
currentDateTime = datetime.now()
date = currentDateTime.date()
year = date.strftime("%Y") #except: 2022

date.strftime("%Y")

d = datetime.now()
only_date, only_time = d.date(), d.time()
only_date = only_date.strftime('%Y.%m.%d')
only_time = only_time.strftime('%H.%M')


tabname = "GDriveLockErrors"

FileName = output + only_date + "_" + only_time + " " + tabname + " Combined.xlsx"

column_order = ['id','Filename', 'Errortype', 'ErrorIssue', 'Path', 'webViewLink']
with pd.ExcelWriter(FileName) as writer:
    df1[column_order].to_excel(writer, sheet_name=tabname, index=True)
